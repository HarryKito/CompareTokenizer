# %% [markdown]
# # MeCab

# %%
# Target to Tokenizer
text = """
この件はお持ち帰りして検討させていただいてよろしいでしょうか。
即答できなく恐縮ですが
一応内部でまとめますので申し訳ございませんが後程またよろしくお願いいたします。
"""

# %%
import MeCab

import rhoknp

# %%
wakati = MeCab.Tagger("-Owakati")

# %%
wakati.parse(text).split()
# Out:
# ['この',
#  '件',
#  'は',
#  'お',
#  '持ち帰り',
#  'し',
#  'て',
#  '検討',
#  'さ',
#  'せ',
#  'て',
#  'いただい',
#  'て',
#  'よろしい',
#  'でしょ',
#  'う',
#  'か',
#  '。',
#  '即答',
#  'でき',
#  'なく',
#  '恐縮',
#  'です',
#  'が',
#  '一応',
#  '内部',
#  'で',
#  'まとめ',
#  'ます',
#  'ので',
#  '申し訳',
#  'ござい',
#  'ませ',
#  'ん',
#  'が',
#  '後程',
#  'また',
#  'よろしく',
#  'お願い',
#  'いたし',
#  'ます',
#  '。']

# %% [markdown]
# # jumanpp

# %%
# !brew install jumanpp
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with `$HOMEBREW_AUTO_UPDATE_SECS` or disable with
# `$HOMEBREW_NO_AUTO_UPDATE=1`. Hide these hints with `$HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# astra: Command-Line Interface for DataStax Astra
# docker-language-server: Language server for Dockerfiles, Compose files, and Bake files
# git-get: Better way to clone, organize and manage multiple git repositories
# neo4j-mcp: Neo4j official Model Context Protocol server for AI tools
# ==> New Casks
# datadog-security-cli: Datadog Security Product CLI
# font-guguru-sans-code
# font-guguru-sans-code-nf
# mpluginmanager: Installer for MeldaProduction audio plugins
# uuremote: NetEase UU remote desktop access and control tool
#
# You have 54 outdated formulae and 1 outdated cask installed.
#
# ==> Fetching downloads for: jumanpp
# ...

# %%
import sys
print(sys.executable)
# !which jumanpp
# Out:
# /usr/local/opt/python@3.13/bin/python3.13
# /usr/local/bin/jumanpp

# %%
jumapp = rhoknp.Jumanpp()
# Out:
# failed to start Juman++: Operation timed out after 10 seconds.

# %%
sentence = jumapp.apply_to_sentence(text)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sentence = jumapp.apply_to_sentence(text)
#
# File ~/miniconda3/lib/python3.9/site-packages/rhoknp/processors/jumanpp.py:133, in Jumanpp.apply_to_sentence(self, sentence, timeout)
#     126 """文に Jumanpp を適用する．
#     127
#     128 Args:
#     129     sentence: 文．
#     130     timeout: 最大処理時間．
#     131 """
#     132 if not self.is_available():
# --> 133     raise RuntimeError("Juman++ is not available.")
#     135 if isinstance(sentence, str):
#     136     sentence = Sentence(sentence)
#
# RuntimeError: Juman++ is not available.
